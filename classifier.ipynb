# %%
from pathlib import Path
import spikeinterface.extractors as si

# %%
patient = "DA047 Sorted"
session = "12-13"

base_path = Path("/Users/marco/Local_Sorting")
# session_path = base_path / patient / session
sort_path = session_path / "sort"
raw_path = session_path / "raw/micros"

# positive_dir = sort_path / "5.1"
# negative_dir = sort_path / "5.2"
# final_dir = sort_path / "final"

# raw_file = si.read_neuralynx(raw_path)
# num_channels = len(raw_file.channel_ids)
# print(num_channels)
# Out:
# 16

# %%
# Written by Marco

import numpy as np
import scipy.io
from pathlib import Path


# Load spike output from .mat file, or empty dictionary if empty

def safe_load(path = sort_path):
    """Load .mat if it exists, otherwise return empty dict."""
    return scipy.io.loadmat(path) if Path(path).exists() else {}


def create_spike_summary(sort_path = sort_path, electrode_num=1, patient=patient, session=session):
    positive_file = sort_path / f"5.1/A_ss{electrode_num}_sorted_new.mat"
    negative_file = sort_path / f"5.2/A_ss{electrode_num}_sorted_new.mat"
    final_max = sort_path / f"final/A_ss{electrode_num}_Max_sorted_new.mat"
    final_min = sort_path / f"final/A_ss{electrode_num}_Min_sorted_new.mat"

    positive_spikes = safe_load(positive_file)
    negative_spikes = safe_load(negative_file)
    final_max_spikes = safe_load(final_max)
    final_min_spikes = safe_load(final_min)

    # Compile spike sorting data into single dictionary
    spike_summary = {
        "Patient": f"{patient}",
        "Session": f"{session}",
        "Channel": f"{electrode_num}",
        "Positive Data": {
            "Positive Spikes": positive_spikes.get("useNegative", np.array([])).T,
            "Positive Merged": positive_spikes.get("useNegativeMerged", np.array([])),
        },
        "Negative Data": {
            "Negative Spikes": negative_spikes.get("useNegative", np.array([])).T,
            "NegativeMerged": negative_spikes.get("useNegativeMerged", np.array([])),
        },
        "Final Max": {
            "included": final_max_spikes.get("useNegative", np.array([])),
            "excluded": final_max_spikes.get("useNegativeExcluded", np.array([])).T,
        },
        "Final Min": {
            "included": final_min_spikes.get("useNegative", np.array([])),
            "excluded": final_min_spikes.get("useNegativeExcluded", np.array([])).T,
        },
    }
     #Create a list that includes patient data
    Patient_Data = (spike_summary["Patient"], spike_summary["Session"], spike_summary["Channel"])

    # Make a python dictionary of good units
    good_units = {
        # "info": Patient_Data,
        "Positive Included": spike_summary["Final Max"]["included"].tolist(),
        "Negative Included": spike_summary["Final Min"]["included"].tolist()
    }

    # by default include the spikes listed in the final directory
    if spike_summary["Final Max"]["included"].size != 0 or spike_summary["Final Min"]["included"].size != 0:
        noise = {
            # "info": Patient_Data,
            "Positive Noise": spike_summary["Final Max"]["excluded"].tolist() ,
            "Negative Noise": spike_summary["Final Min"]["excluded"].tolist(),
        }
    # if the final directory is empty, then load the spikes identified in 5.1 / 5.2, and in that case 
    else:
        noise = {
            # "info": Patient_Data,
            "Positive Noise": spike_summary["Positive Data"]["Positive Spikes"].tolist(),
            "Negative Noise": spike_summary["Negative Data"]["Negative Spikes"].tolist()
        }
        
    return Patient_Data, good_units, noise

patient_data, good_units, noise = create_spike_summary(electrode_num=3, patient = "DA047 Sorted", session = "12-13")
print("patient_data", patient_data)
print("good units: ", good_units)
print("noise: ", noise)
# Out:
# patient_data ('DA047 Sorted', '12-13', '3')
# good units:  {'Positive Included': [[3634, 3804, 4042, 4093, 4143, 4158]], 'Negative Included': [[5007, 5181, 5261, 5364, 5494]]}
# noise:  {'Positive Noise': [[3602, 3677, 3775, 3940, 4074]], 'Negative Noise': [[1649, 1650, 2115, 2212, 2433, 4162, 4568, 4585, 4726, 5190, 5253, 5376, 5389, 5460, 5485]]}

# %%
i = 0
def create_bag_of_spikes(i):
    
    # target label (e.g., from your good_units)
    lbl = int(good_units["Positive Included"][0][i])

    # flatten labels safely
    labels = np.array(positive_spikes.get("assignedNegative", np.array([]))).ravel()

    # pick the waveform matrix to slice
    W = np.array(positive_spikes.get("allSpikesCorrFree", np.array([])))

    # build mask: match label and ignore zeros
    mask = (labels == lbl) & (labels != 0)

    # slice; result is (n_selected_spikes, n_samples)
    waveforms_for_label = W[mask] if (W.size and labels.size) else np.array([])

    # optional: count selected spikes
    n_selected = int(mask.sum()) if labels.size else 0

    spike_dict = {"Patient Data": Patient_Data,
    "Spike Label": lbl,
    "Number of Spikes": n_selected,
    "Spikes": waveforms_for_label
    }

    return spike_dict


bag_0 = create_bag_of_spikes(1)
bag_0
# Out:
# {'Patient Data': ('DA047 Sorted', '12-13', '15'),
#  'Spike Label': 4023,
#  'Number of Spikes': 332,
#  'Spikes': array([[-0.00766344, -0.00766344, -0.00766344, ..., -0.22314554,
#           0.03320956,  0.1151993 ],
#         [-0.39866404, -0.39866404, -0.39866404, ..., -1.04854944,
#          -0.81387112, -0.74724279],
#         [-0.38320734, -0.38320734, -0.38320734, ..., -0.27450319,
#          -0.28213579, -0.32498458],
#         ...,
#         [ 0.40969492,  0.40969492,  0.40969492, ...,  0.49720991,
#           0.38197632,  0.24522426],
#         [ 0.03832915,  0.03832915,  0.03832915, ...,  0.4282705 ,
#           0.61119347,  0.69317112],
#         [ 1.33231828,  1.33231828,  1.33231828, ..., -0.01799642,
#          -0.10343879, -0.36783007]])}

# %%
# There is a syntax error here due to invalid argument annotations in the function definition.
# In Python, you can use type hints like def func(arg1: type, arg2: type), but 'good_units[array]' is not valid.
# Remove '[array]' from the function argument list:

import numpy as np

def get_units(good_units: dict,
              noise: dict,
              alignment: str,
              spike_type: str):
    # pick source dict
    src = good_units if spike_type == "good_units" else noise

    # key map
    key_map = {
        ("positive", "good_units"): "Positive Included",
        ("negative", "good_units"): "Negative Included",
        ("positive", "noise"): "Positive Noise",
        ("negative", "noise"): "Negative Noise",
    }

    key = key_map.get((alignment, spike_type), None)
    if key is None:
        return []

    arr = src.get(key, [])
    if isinstance(arr, (list, np.ndarray)) and len(arr) > 0:
        return arr[0]
    return []


# example
# print(get_units(good_units, noise, "negative", "noise"))


print(get_units(good_units, noise, "positive", "noise"))
# Out:
# [701, 4803, 4963, 4752, 4701, 2934, 3007, 4651, 5282, 5319, 5125, 4854, 5128]

# %%
# Written by Marco

def create_bag_of_spikes(electrode_num=0, spike_num=0, patient_data=patient_data, alignment = "positive", spike_type = "noise"):
    positive_file = sort_path / f"5.1/A_ss{electrode_num}_sorted_new.mat"
    negative_file = sort_path / f"5.2/A_ss{electrode_num}_sorted_new.mat"
    # final_max = sort_path / f"final/A_ss{electrode_num}_Max_sorted_new.mat"
    # final_min = sort_path / f"final/A_ss{electrode_num}_Min_sorted_new.mat"

    positive_spikes = safe_load(positive_file)
    negative_spikes = safe_load(negative_file)
    
    # The final spikes arent needed because in all cases the original spike file is stored in sort/5.1 and sort/5.2
    # final_max_spikes = safe_load(final_max)
    # final_min_spikes = safe_load(final_min)

    if spike_type =="noise":
        if alignment == "positive":    
            # target label (e.g., from your good_units)
            lbl = int(noise["Positive Noise"][0][spike_num]) if len(noise["Positive Noise"]) > 0 else []

            # flatten labels safely
            labels = np.array(positive_spikes.get("assignedNegative", np.array([]))).ravel()

            # pick the waveform matrix to slice
            W = np.array(positive_spikes.get("allSpikesCorrFree", np.array([])))

        else:  
            # target label (e.g., from your good_units)
            lbl = int(noise["Negative Noise"][0][spike_num]) if len(noise["Negative Noise"]) > 0 else []

            # flatten labels safely
            labels = np.array(negative_spikes.get("assignedNegative", np.array([]))).ravel()

            # pick the waveform matrix to slice
            W = np.array(negative_spikes.get("allSpikesCorrFree", np.array([])))
    else:
        if alignment == "positive":    
            # target label (e.g., from your good_units)
            lbl = int(good_units["Positive Included"][0][spike_num]) if len(good_units["Positive Included"]) > 0 else []

            # flatten labels safely
            labels = np.array(positive_spikes.get("assignedNegative", np.array([]))).ravel()

            # pick the waveform matrix to slice
            W = np.array(positive_spikes.get("allSpikesCorrFree", np.array([])))

        else:  
            # target label (e.g., from your good_units)
            lbl = int(good_units["Negative Included"][0][spike_num]) if len(good_units["Negative Included"]) > 0 else []

            # flatten labels safely
            labels = np.array(negative_spikes.get("assignedNegative", np.array([]))).ravel()

            # pick the waveform matrix to slice
            W = np.array(negative_spikes.get("allSpikesCorrFree", np.array([]))) 

    # build mask: match label and ignore zeros
    mask = (labels == lbl) & (labels != 0)

    # slice; result is (n_selected_spikes, n_samples)
    waveforms_for_label = W[mask] if (W.size and labels.size) else np.array([])

    # optional: count selected spikes
    n_selected = int(mask.sum()) if labels.size else 0

    spike_dict = {"patient data": patient_data,
    "spike label": lbl,
    "number of spikes": n_selected,
    "spike_type": spike_type,
    "alignment": alignment,
    "spikes": waveforms_for_label
    }

    return spike_dict

bag_1 = create_bag_of_spikes(electrode_num=3, spike_num=3, patient_data=patient_data, alignment = "positive")
bag_1
# Out:
# {'patient data': ('DA047 Sorted', '12-13', '1'),
#  'spike label': 4752,
#  'number of spikes': 0,
#  'spike_type': 'noise',
#  'alignment': 'positive',
#  'spikes': array([], shape=(0, 256), dtype=float64)}

# %%
# Written by Chat

import numpy as np
from typing import Any, Dict, Tuple, Optional

def _as_list_first(seq: Any):
    """Return a flat Python list. If list-of-lists/ndarrays, take first inner."""
    if isinstance(seq, np.ndarray):
        seq = seq.tolist()
    if not isinstance(seq, list) or not seq:
        return []
    first = seq[0]
    if isinstance(first, np.ndarray):
        return first.tolist()
    if isinstance(first, list):
        return first
    return seq

def _safe_label(src: Dict[str, Any], key: str, idx: int) -> Optional[int]:
    """
    Safely fetch src[key] possibly shaped like [[...]] or ndarray,
    return element at idx as int, or None if missing/out-of-range.
    """
    flat = _as_list_first(src.get(key, []))
    if 0 <= idx < len(flat):
        try:
            return int(flat[idx])
        except Exception:
            return None
    return None

def create_bag_of_spikes(
    electrode_num: int = 0,
    spike_num: int = 0,
    patient_data: Any = None,
    alignment: str = "positive",       # "positive" | "negative"
    spike_type: str = "noise"          # "noise" | "good_units"
):
    # expects globals: sort_path, safe_load, noise, good_units
    pos_file = sort_path / f"5.1/A_ss{electrode_num}_sorted_new.mat"
    neg_file = sort_path / f"5.2/A_ss{electrode_num}_sorted_new.mat"

    pos = safe_load(pos_file)
    neg = safe_load(neg_file)

    # choose spike dict by alignment
    spikes = pos if alignment == "positive" else neg

    # choose label source dict and key
    if spike_type == "noise":
        label_src: Dict[str, Any] = noise
        label_key = "Positive Noise" if alignment == "positive" else "Negative Noise"
    else:
        label_src = good_units
        label_key = "Positive Included" if alignment == "positive" else "Negative Included"

    # safe label extraction
    lbl = _safe_label(label_src, label_key, spike_num)

    # flatten labels and pick waveform matrix
    labels = np.array(spikes.get("assignedNegative", np.array([]))).ravel()
    W = np.array(spikes.get("allSpikesCorrFree", np.array([])))

    # build mask only if we have a label and arrays are non-empty
    if lbl is not None and labels.size and W.size:
        # guard dimension mismatch (labels should match W rows)
        n_rows = W.shape[0]
        if labels.shape[0] != n_rows:
            # trim to the shorter length to avoid index errors
            n = min(n_rows, labels.shape[0])
            W = W[:n]
            labels = labels[:n]
        mask = (labels == lbl) & (labels != 0)
        waveforms_for_label = W[mask]
        n_selected = int(mask.sum())
    else:
        waveforms_for_label = np.array([])
        n_selected = 0

    return {
        "patient data": patient_data,
        "spike label": lbl,
        "number of spikes": n_selected,
        "spike_type": spike_type,
        "alignment": alignment,
        "spikes": waveforms_for_label,
    }

# example call (uses your globals noise/good_units/sort_path/safe_load/patient_data):
bag_1 = create_bag_of_spikes(electrode_num=1, spike_num=0, patient_data=patient_data, alignment="positive", spike_type="noise")

# %%
bag_1
# Out:
# {'patient data': ('DA047 Sorted', '12-13', '1'),
#  'spike label': 701,
#  'number of spikes': 79,
#  'spike_type': 'noise',
#  'alignment': 'positive',
#  'spikes': array([[-0.52701887, -0.52701887, -0.52701887, ..., -0.39468965,
#          -0.58021059, -0.74705469],
#         [ 0.22877798,  0.22877798,  0.22877798, ..., -0.58857936,
#          -0.54955398, -0.55416127],
#         [ 0.57100215,  0.57100215,  0.57100215, ..., -0.00713703,
#           0.19888277,  0.34133471],
#         ...,
#         [-0.6481804 , -0.6481804 , -0.6481804 , ..., -1.36424797,
#          -1.42281428, -1.45733443],
#         [ 0.65367604,  0.65367604,  0.65367604, ..., -0.13056104,
#           0.01292183,  0.12577971],
#         [-0.24687845, -0.24687845, -0.24687845, ..., -1.15873753,
#          -1.22594925, -1.34878511]])}

# %%
# Written by Marco

import os

patient_data, good_units, noise = create_spike_summary(electrode_num=1, patient = "DA047 Sorted", session = "12-13")

def list_subdirectories(dir_path):
    file_list = [name for name in os.listdir(dir_path) if os.path.isdir(os.path.join(dir_path, name))]
    print(dir_path, "contains", file_list)
    return file_list

def create_bag_of_bags(num_channels, patient_path, patient = "DA047 Sorted"):
    # get positive and negative allignment
    alignments = ["positive", "negative"]
    spike_type = ["noise", "good_units"]
    # include all sessions
    subdirs = list_subdirectories(patient_path)
    bag_of_bags = []
    for dir in subdirs:
        for channel in range(int(num_channels)+1):
            print(dir, channel)
            patient_data, good_units, noise = create_spike_summary(electrode_num=channel, patient = patient, session = dir)
            for type in spike_type:
                for alignment in alignments:
                    units = get_units(good_units, noise, alignment = alignment, spike_type = type)
                    print(units)
                    num_units = range(len(units))
                    for unit in num_units:
                        bag = create_bag_of_spikes(electrode_num=channel, spike_num=unit, patient_data=patient_data, alignment = alignment, spike_type=type)
                        bag_of_bags.append(bag)
                        return unit
                        print(" Unit: ", unit, "from channel: ", channel, "Is Done!")
    return bag_of_bags

# %%
DA047_Bag = create_bag_of_bags(num_channels=3, patient = "DA047 Sorted", patient_path = "/Users/marco/Local_Sorting/DA047 Sorted")
print(DA047_Bag)
# Out:
# /Users/marco/Local_Sorting/DA047 Sorted contains ['12-15', '12-13', '12-16']
# 12-15 0
# []
# []
# []
# []
# 12-15 1
# [701, 4803, 4963, 4752, 4701, 2934, 3007, 4651, 5282, 5319, 5125, 4854, 5128]
# 0

# %%
# Written by Chat

import os

# assume: create_spike_summary, get_units, create_bag_of_spikes exist

def list_subdirectories(dir_path: str):
    names = os.listdir(dir_path)
    subdirs = [n for n in names if os.path.isdir(os.path.join(dir_path, n))]
    print(dir_path, "contains", subdirs)
    return subdirs

def create_bag_of_bags(
    num_channels: int,
    patient_path: str,
    patient: str = "DA047 Sorted",
):
    alignments = ("positive", "negative")
    spike_kinds = ("noise", "good_units")

    sessions = list_subdirectories(patient_path)
    bag_of_bags = []

    for session_dir in sessions:
        for channel in range(int(num_channels)):  # 0..num_channels-1
            patient_data, gu, nz = create_spike_summary(
                electrode_num=channel, patient=patient, session=session_dir
            )

            for spike_kind in spike_kinds:
                for alignment in alignments:
                    units = get_units(gu, nz, alignment=alignment, spike_type=spike_kind)
                    for unit_idx in range(len(units)+1):
                        bag = create_bag_of_spikes(
                            electrode_num=channel,
                            spike_num=unit_idx,
                            patient_data=patient_data,
                            alignment=alignment,
                            spike_type=spike_kind
                            # pass dicts explicitly to avoid stale globals
                            # good_units=gu,
                            # noise=nz,
                        )
                        bag_of_bags.append(bag)
                        print(
                            f"Session={session_dir} "
                            f"Channel={channel} "
                            f"Kind={spike_kind} "
                            f"Align={alignment} "
                            f"Unit={unit_idx} done"
                        )
        print()  # spacer per session

    return bag_of_bags

# %%
DA047_Bag = create_bag_of_bags(num_channels=3, patient = "DA047 Sorted", patient_path = "/Users/marco/Local_Sorting/DA047 Sorted")
print(DA047_Bag)
# Out:
# /Users/marco/Local_Sorting/DA047 Sorted contains ['12-15', '12-13', '12-16']
# Session=12-15 Channel=0 Kind=noise Align=positive Unit=0 done
# Session=12-15 Channel=0 Kind=noise Align=negative Unit=0 done
# Session=12-15 Channel=0 Kind=good_units Align=positive Unit=0 done
# Session=12-15 Channel=0 Kind=good_units Align=negative Unit=0 done
# Session=12-15 Channel=1 Kind=noise Align=positive Unit=0 done
# Session=12-15 Channel=1 Kind=noise Align=positive Unit=1 done
# Session=12-15 Channel=1 Kind=noise Align=positive Unit=2 done
# Session=12-15 Channel=1 Kind=noise Align=positive Unit=3 done
# Session=12-15 Channel=1 Kind=noise Align=positive Unit=4 done
# Session=12-15 Channel=1 Kind=noise Align=positive Unit=5 done
# Session=12-15 Channel=1 Kind=noise Align=positive Unit=6 done
# Session=12-15 Channel=1 Kind=noise Align=positive Unit=7 done
# Session=12-15 Channel=1 Kind=noise Align=positive Unit=8 done
# Session=12-15 Channel=1 Kind=noise Align=positive Unit=9 done
# Session=12-15 Channel=1 Kind=noise Align=positive Unit=10 done
# Session=12-15 Channel=1 Kind=noise Align=positive Unit=11 done
# Session=12-15 Channel=1 Kind=noise Align=positive Unit=12 done
# Session=12-15 Channel=1 Kind=noise Align=positive Unit=13 done
# Session=12-15 Channel=1 Kind=noise Align=negative Unit=0 done
# Session=12-15 Channel=1 Kind=noise Align=negative Unit=1 done
# Session=12-15 Channel=1 Kind=noise Align=negative Unit=2 done
# Session=12-15 Channel=1 Kind=noise Align=negative Unit=3 done
# Session=12-15 Channel=1 Kind=noise Align=negative Unit=4 done
# Session=12-15 Channel=1 Kind=noise Align=negative Unit=5 done
# Session=12-15 Channel=1 Kind=noise Align=negative Unit=6 done
# Session=12-15 Channel=1 Kind=noise Align=negative Unit=7 done
# Session=12-15 Channel=1 Kind=noise Align=negative Unit=8 done
# Session=12-15 Channel=1 Kind=noise Align=negative Unit=9 done
# Session=12-15 Channel=1 Kind=noise Align=negative Unit=10 done
# Session=12-15 Channel=1 Kind=good_units Align=positive Unit=0 done
# Session=12-15 Channel=1 Kind=good_units Align=negative Unit=0 done
# Session=12-15 Channel=1 Kind=good_units Align=negative Unit=1 done
# Session=12-15 Channel=2 Kind=noise Align=positive Unit=0 done
# Session=12-15 Channel=2 Kind=noise Align=positive Unit=1 done
# Session=12-15 Channel=2 Kind=noise Align=positive Unit=2 done
# Session=12-15 Channel=2 Kind=noise Align=negative Unit=0 done
# Session=12-15 Channel=2 Kind=noise Align=negative Unit=1 done
# Session=12-15 Channel=2 Kind=noise Align=negative Unit=2 done
# Session=12-15 Channel=2 Kind=good_units Align=positive Unit=0 done
# Session=12-15 Channel=2 Kind=good_units Align=negative Unit=0 done
#
# Session=12-13 Channel=0 Kind=noise Align=positive Unit=0 done
# Session=12-13 Channel=0 Kind=noise Align=negative Unit=0 done
# Session=12-13 Channel=0 Kind=good_units Align=positive Unit=0 done
# Session=12-13 Channel=0 Kind=good_units Align=negative Unit=0 done
# Session=12-13 Channel=1 Kind=noise Align=positive Unit=0 done
# Session=12-13 Channel=1 Kind=noise Align=positive Unit=1 done
# Session=12-13 Channel=1 Kind=noise Align=positive Unit=2 done
# Session=12-13 Channel=1 Kind=noise Align=positive Unit=3 done
# Session=12-13 Channel=1 Kind=noise Align=positive Unit=4 done
# Session=12-13 Channel=1 Kind=noise Align=positive Unit=5 done
# Session=12-13 Channel=1 Kind=noise Align=positive Unit=6 done
# Session=12-13 Channel=1 Kind=noise Align=positive Unit=7 done
# Session=12-13 Channel=1 Kind=noise Align=positive Unit=8 done
# Session=12-13 Channel=1 Kind=noise Align=positive Unit=9 done
# Session=12-13 Channel=1 Kind=noise Align=positive Unit=10 done
# Session=12-13 Channel=1 Kind=noise Align=positive Unit=11 done
# Session=12-13 Channel=1 Kind=noise Align=positive Unit=12 done
# Session=12-13 Channel=1 Kind=noise Align=positive Unit=13 done
# Session=12-13 Channel=1 Kind=noise Align=negative Unit=0 done
# Session=12-13 Channel=1 Kind=noise Align=negative Unit=1 done
# Session=12-13 Channel=1 Kind=noise Align=negative Unit=2 done
# Session=12-13 Channel=1 Kind=noise Align=negative Unit=3 done
# Session=12-13 Channel=1 Kind=noise Align=negative Unit=4 done
# Session=12-13 Channel=1 Kind=noise Align=negative Unit=5 done
# Session=12-13 Channel=1 Kind=noise Align=negative Unit=6 done
# Session=12-13 Channel=1 Kind=noise Align=negative Unit=7 done
# Session=12-13 Channel=1 Kind=noise Align=negative Unit=8 done
# Session=12-13 Channel=1 Kind=noise Align=negative Unit=9 done
# Session=12-13 Channel=1 Kind=noise Align=negative Unit=10 done
# Session=12-13 Channel=1 Kind=good_units Align=positive Unit=0 done
# Session=12-13 Channel=1 Kind=good_units Align=negative Unit=0 done
# Session=12-13 Channel=1 Kind=good_units Align=negative Unit=1 done
# Session=12-13 Channel=2 Kind=noise Align=positive Unit=0 done
# Session=12-13 Channel=2 Kind=noise Align=positive Unit=1 done
# Session=12-13 Channel=2 Kind=noise Align=positive Unit=2 done
# Session=12-13 Channel=2 Kind=noise Align=negative Unit=0 done
# Session=12-13 Channel=2 Kind=noise Align=negative Unit=1 done
# Session=12-13 Channel=2 Kind=noise Align=negative Unit=2 done
# Session=12-13 Channel=2 Kind=good_units Align=positive Unit=0 done
# Session=12-13 Channel=2 Kind=good_units Align=negative Unit=0 done
#
# Session=12-16 Channel=0 Kind=noise Align=positive Unit=0 done
# Session=12-16 Channel=0 Kind=noise Align=negative Unit=0 done
# Session=12-16 Channel=0 Kind=good_units Align=positive Unit=0 done
# Session=12-16 Channel=0 Kind=good_units Align=negative Unit=0 done
# Session=12-16 Channel=1 Kind=noise Align=positive Unit=0 done
# Session=12-16 Channel=1 Kind=noise Align=positive Unit=1 done
# Session=12-16 Channel=1 Kind=noise Align=positive Unit=2 done
# Session=12-16 Channel=1 Kind=noise Align=positive Unit=3 done
# Session=12-16 Channel=1 Kind=noise Align=positive Unit=4 done
# Session=12-16 Channel=1 Kind=noise Align=positive Unit=5 done
# Session=12-16 Channel=1 Kind=noise Align=positive Unit=6 done
# Session=12-16 Channel=1 Kind=noise Align=positive Unit=7 done
# Session=12-16 Channel=1 Kind=noise Align=positive Unit=8 done
# Session=12-16 Channel=1 Kind=noise Align=positive Unit=9 done
# Session=12-16 Channel=1 Kind=noise Align=positive Unit=10 done
# Session=12-16 Channel=1 Kind=noise Align=positive Unit=11 done
# Session=12-16 Channel=1 Kind=noise Align=positive Unit=12 done
# Session=12-16 Channel=1 Kind=noise Align=positive Unit=13 done
# Session=12-16 Channel=1 Kind=noise Align=negative Unit=0 done
# Session=12-16 Channel=1 Kind=noise Align=negative Unit=1 done
# Session=12-16 Channel=1 Kind=noise Align=negative Unit=2 done
# Session=12-16 Channel=1 Kind=noise Align=negative Unit=3 done
# Session=12-16 Channel=1 Kind=noise Align=negative Unit=4 done
# Session=12-16 Channel=1 Kind=noise Align=negative Unit=5 done
# Session=12-16 Channel=1 Kind=noise Align=negative Unit=6 done
# Session=12-16 Channel=1 Kind=noise Align=negative Unit=7 done
# Session=12-16 Channel=1 Kind=noise Align=negative Unit=8 done
# Session=12-16 Channel=1 Kind=noise Align=negative Unit=9 done
# Session=12-16 Channel=1 Kind=noise Align=negative Unit=10 done
# Session=12-16 Channel=1 Kind=good_units Align=positive Unit=0 done
# Session=12-16 Channel=1 Kind=good_units Align=negative Unit=0 done
# Session=12-16 Channel=1 Kind=good_units Align=negative Unit=1 done
# Session=12-16 Channel=2 Kind=noise Align=positive Unit=0 done
# Session=12-16 Channel=2 Kind=noise Align=positive Unit=1 done
# Session=12-16 Channel=2 Kind=noise Align=positive Unit=2 done
# Session=12-16 Channel=2 Kind=noise Align=negative Unit=0 done
# Session=12-16 Channel=2 Kind=noise Align=negative Unit=1 done
# Session=12-16 Channel=2 Kind=noise Align=negative Unit=2 done
# Session=12-16 Channel=2 Kind=good_units Align=positive Unit=0 done
# Session=12-16 Channel=2 Kind=good_units Align=negative Unit=0 done
#
# [{'patient data': ('DA047 Sorted', '12-15', '0'), 'spike label': 701, 'number of spikes': 0, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([], dtype=float64)}, {'patient data': ('DA047 Sorted', '12-15', '0'), 'spike label': 3850, 'number of spikes': 0, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([], dtype=float64)}, {'patient data': ('DA047 Sorted', '12-15', '0'), 'spike label': None, 'number of spikes': 0, 'spike_type': 'good_units', 'alignment': 'positive', 'spikes': array([], dtype=float64)}, {'patient data': ('DA047 Sorted', '12-15', '0'), 'spike label': 4717, 'number of spikes': 0, 'spike_type': 'good_units', 'alignment': 'negative', 'spikes': array([], dtype=float64)}, {'patient data': ('DA047 Sorted', '12-15', '1'), 'spike label': 701, 'number of spikes': 79, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[-0.52701887, -0.52701887, -0.52701887, ..., -0.39468965,
#         -0.58021059, -0.74705469],
#        [ 0.22877798,  0.22877798,  0.22877798, ..., -0.58857936,
#         -0.54955398, -0.55416127],
#        [ 0.57100215,  0.57100215,  0.57100215, ..., -0.00713703,
#          0.19888277,  0.34133471],
#        ...,
#        [-0.6481804 , -0.6481804 , -0.6481804 , ..., -1.36424797,
#         -1.42281428, -1.45733443],
#        [ 0.65367604,  0.65367604,  0.65367604, ..., -0.13056104,
#          0.01292183,  0.12577971],
#        [-0.24687845, -0.24687845, -0.24687845, ..., -1.15873753,
#         -1.22594925, -1.34878511]])}, {'patient data': ('DA047 Sorted', '12-15', '1'), 'spike label': 4803, 'number of spikes': 84, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[-1.79023345, -1.79023345, -1.79023345, ...,  1.15054443,
#          1.20328937,  0.99146787],
#        [ 0.28609088,  0.28609088,  0.28609088, ..., -0.05922048,
#         -0.07564397, -0.0717835 ],
#        [ 1.14897774,  1.14897774,  1.14897774, ...,  0.34387582,
#          0.68148718,  0.99747271],
#        ...,
#        [-1.04365801, -1.04365801, -1.04365801, ...,  0.66511436,
#          0.82711225,  0.97056409],
#        [ 0.20046279,  0.20046279,  0.20046279, ..., -0.12706155,
#         -0.10275103, -0.00437162],
#        [-0.40756574, -0.40756574, -0.40756574, ..., -0.52887413,
#         -0.49660638, -0.41679855]])}, {'patient data': ('DA047 Sorted', '12-15', '1'), 'spike label': 4963, 'number of spikes': 124, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[-0.27057913, -0.27057913, -0.27057913, ...,  0.86395185,
#          0.90125534,  0.86048668],
#        [ 0.51374765,  0.51374765,  0.51374765, ..., -1.04885675,
#         -1.02179134, -0.9718434 ],
#        [-0.50625322, -0.50625322, -0.50625322, ..., -1.02543465,
#         -0.89211196, -0.77763545],
#        ...,
#        [-0.486811  , -0.486811  , -0.486811  , ..., -0.8149116 ,
#         -0.71307022, -0.59044112],
#        [-0.0153786 , -0.0153786 , -0.0153786 , ...,  1.35752312,
#          1.72414962,  1.79066924],
#        [-0.7480665 , -0.7480665 , -0.7480665 , ..., -0.87201777,
#         -0.52830733, -0.18258856]])}, {'patient data': ('DA047 Sorted', '12-15', '1'), 'spike label': 4752, 'number of spikes': 129, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[-1.01059213, -1.01059213, -1.01059213, ..., -0.37879206,
#         -0.42587984, -0.43994185],
#        [ 0.42453209,  0.42453209,  0.42453209, ..., -0.48297434,
#         -0.37454247, -0.24280861],
#        [-0.1507682 , -0.1507682 , -0.1507682 , ..., -0.99137773,
#         -0.88703348, -0.70690804],
#        ...,
#        [ 0.11667829,  0.11667829,  0.11667829, ...,  1.197213  ,
#          1.44156666,  1.65977301],
#        [ 1.30839866,  1.30839866,  1.30839866, ...,  0.90841164,
#          0.79870976,  0.57892243],
#        [ 1.0140663 ,  1.0140663 ,  1.0140663 , ...,  0.29238322,
#          0.56861662,  0.81148683]])}, {'patient data': ('DA047 Sorted', '12-15', '1'), 'spike label': 4701, 'number of spikes': 138, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[-0.54013348, -0.54013348, -0.54013348, ..., -1.03188203,
#         -1.14979515, -1.12145123],
#        [-0.50512488, -0.50512488, -0.50512488, ..., -1.45903963,
#         -1.41227738, -1.35586377],
#        [-0.47547426, -0.47547426, -0.47547426, ..., -0.27363866,
#         -0.15506056,  0.12093351],
#        ...,
#        [ 0.19574029,  0.19574029,  0.19574029, ..., -1.4241772 ,
#         -1.60083837, -1.72998219],
#        [-0.80075579, -0.80075579, -0.80075579, ...,  0.09976946,
#          0.02215386, -0.0616391 ],
#        [ 0.08767616,  0.08767616,  0.08767616, ..., -0.76159073,
#         -0.80186677, -0.83945608]])}, {'patient data': ('DA047 Sorted', '12-15', '1'), 'spike label': 2934, 'number of spikes': 218, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[-1.31874334, -1.31874334, -1.31874334, ...,  2.34395727,
#          2.32699768,  2.72096939],
#        [ 0.78753261,  0.78753261,  0.78753261, ...,  0.02093963,
#          0.05176057,  0.02208206],
#        [-0.45089689, -0.45089689, -0.45089689, ...,  0.08999822,
#         -0.05432042,  0.06340459],
#        ...,
#        [-0.68407099, -0.68407099, -0.68407099, ..., -0.08479122,
#         -0.1510512 , -0.11338694],
#        [ 1.9369842 ,  1.9369842 ,  1.9369842 , ..., -1.33169672,
#         -1.30356435, -1.24723248],
#        [-0.46979218, -0.46979218, -0.46979218, ..., -0.11056359,
#         -0.29550409, -0.46908412]])}, {'patient data': ('DA047 Sorted', '12-15', '1'), 'spike label': 3007, 'number of spikes': 316, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[ 0.05225007,  0.05225007,  0.05225007, ...,  1.96057007,
#          1.7959047 ,  1.56679955],
#        [ 0.16263878,  0.16263878,  0.16263878, ..., -0.80504862,
#         -0.38415578,  0.04389376],
#        [ 0.32460897,  0.32460897,  0.32460897, ...,  0.2113784 ,
#          0.27293996,  0.35070729],
#        ...,
#        [ 1.41382835,  1.41382835,  1.41382835, ...,  0.02601716,
#         -0.03425844, -0.06966663],
#        [-0.04636347, -0.04636347, -0.04636347, ...,  0.43988079,
#          0.46612798,  0.48342214],
#        [ 0.2134538 ,  0.2134538 ,  0.2134538 , ..., -2.21693253,
#         -1.72193294, -1.1746038 ]])}, {'patient data': ('DA047 Sorted', '12-15', '1'), 'spike label': 4651, 'number of spikes': 466, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[-2.6136257 , -2.6136257 , -2.6136257 , ...,  0.9825337 ,
#          1.06606428,  1.05120456],
#        [ 0.26620214,  0.26620214,  0.26620214, ..., -0.84204091,
#         -0.68172896, -0.51600789],
#        [ 0.01604635,  0.01604635,  0.01604635, ...,  0.14596181,
#         -0.15755937, -0.03612232],
#        ...,
#        [ 0.12721072,  0.44059851,  0.66785768, ...,  1.08753277,
#          1.08753277,  1.08753277],
#        [-0.07558714, -0.07558714, -0.07558714, ...,  0.17459092,
#          0.2719415 ,  0.3776348 ],
#        [-0.75241483, -0.75241483, -0.75241483, ...,  0.26650064,
#          0.23839571,  0.26572463]])}, {'patient data': ('DA047 Sorted', '12-15', '1'), 'spike label': 5282, 'number of spikes': 570, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[-0.21299668, -0.21299668, -0.21299668, ...,  0.71974654,
#          0.89918754,  0.99885184],
#        [-0.37814533, -0.37814533, -0.37814533, ...,  0.23386778,
#          0.24975287,  0.2360183 ],
#        [-0.3747489 , -0.3747489 , -0.3747489 , ..., -0.70234714,
#         -0.54892729, -0.42010744],
#        ...,
#        [-0.97866299, -0.97866299, -0.97866299, ..., -1.34717575,
#         -1.34576478, -1.34146563],
#        [-1.04562111, -1.04562111, -1.04562111, ...,  0.13834202,
#          0.12229378,  0.14055224],
#        [ 0.29603209,  0.29603209,  0.29603209, ...,  0.17066741,
#          0.12275709,  0.06386094]])}, {'patient data': ('DA047 Sorted', '12-15', '1'), 'spike label': 5319, 'number of spikes': 671, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[ 0.15132119,  0.15132119,  0.15132119, ...,  1.33568942,
#          1.45183267,  1.57296942],
#        [ 0.4187626 ,  0.39241963,  0.3557863 , ...,  0.84016701,
#          0.84016701,  0.84016701],
#        [-0.45669299, -0.45669299, -0.45669299, ...,  0.15424585,
#          0.47396766,  0.7779399 ],
#        ...,
#        [-1.14452767, -1.14452767, -1.14452767, ..., -0.47157629,
#         -0.638973  , -0.72390708],
#        [ 1.0491679 ,  1.0491679 ,  1.0491679 , ...,  0.30668893,
#          0.34801939,  0.41909122],
#        [-0.75605326, -0.75605326, -0.75605326, ...,  0.65725096,
#          0.71627821,  0.8652912 ]])}, {'patient data': ('DA047 Sorted', '12-15', '1'), 'spike label': 5125, 'number of spikes': 825, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[-0.06581804, -0.06581804, -0.06581804, ...,  0.57784877,
#          0.57308878,  0.52663597],
#        [-0.53579354, -0.53579354, -0.53579354, ..., -0.29643778,
#         -0.39174102, -0.48398135],
#        [-0.19562178, -0.19562178, -0.19562178, ..., -0.50095011,
#         -0.46201907, -0.36833992],
#        ...,
#        [-0.92696632, -0.92696632, -0.92696632, ...,  0.43219971,
#          0.4160524 ,  0.39608096],
#        [ 0.28900757,  0.28900757,  0.28900757, ..., -0.06903951,
#         -0.05934369, -0.03528846],
#        [ 0.03427176,  0.03427176,  0.03427176, ..., -0.23932512,
#         -0.35199625, -0.49126137]])}, {'patient data': ('DA047 Sorted', '12-15', '1'), 'spike label': 4854, 'number of spikes': 856, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[ 2.12347864,  2.12347864,  2.12347864, ..., -2.2457678 ,
#         -2.01117189, -1.86065775],
#        [-0.2980294 , -0.2980294 , -0.2980294 , ..., -0.50777773,
#         -0.47475842, -0.47949465],
#        [ 0.11629926,  0.11629926,  0.11629926, ...,  0.43023675,
#          0.61633531,  0.82718389],
#        ...,
#        [ 0.36888665,  0.36888665,  0.36888665, ..., -0.16754674,
#          0.06285296,  0.29045914],
#        [-1.44109765, -1.44109765, -1.44109765, ..., -0.43801901,
#         -0.52787378, -0.58795533],
#        [-1.40970014, -1.40970014, -1.40970014, ..., -0.07130553,
#          0.07717608,  0.12267639]])}, {'patient data': ('DA047 Sorted', '12-15', '1'), 'spike label': 5128, 'number of spikes': 1591, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[ 2.48813999,  2.48813999,  2.48813999, ..., -1.04228541,
#         -1.57177917, -2.01885354],
#        [ 0.14923497,  0.14923497,  0.14923497, ..., -1.38721215,
#         -1.46606525, -1.32959774],
#        [-0.22777976, -0.22777976, -0.22777976, ..., -1.01845744,
#         -0.78680338, -0.6536088 ],
#        ...,
#        [ 0.37373443,  0.37373443,  0.37373443, ...,  0.02969463,
#          0.02603142,  0.16952536],
#        [-0.06054252, -0.06054252, -0.06054252, ...,  0.73703047,
#          0.72022   ,  0.68492621],
#        [-0.06821664, -0.06821664, -0.06821664, ..., -0.48420315,
#         -0.51311004, -0.51874855]])}, {'patient data': ('DA047 Sorted', '12-15', '1'), 'spike label': None, 'number of spikes': 0, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([], dtype=float64)}, {'patient data': ('DA047 Sorted', '12-15', '1'), 'spike label': 3850, 'number of spikes': 61, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[-0.03415769, -0.03415769, -0.03415769, ...,  1.1071466 ,
#          1.13055098,  1.12063954],
#        [ 0.12779562,  0.12779562,  0.12779562, ...,  2.36771951,
#          2.40197288,  2.22118889],
#        [ 0.87518296,  0.87518296,  0.87518296, ...,  0.82128189,
#          0.69073954,  0.59003041],
#        ...,
#        [ 0.69293414,  0.69293414,  0.69293414, ...,  0.52337957,
#          0.57135711,  0.55564019],
#        [ 0.20410287,  0.20410287,  0.20410287, ...,  0.84395742,
#          0.76494884,  0.67357055],
#        [ 1.06453379,  1.06453379,  1.06453379, ..., -1.43029182,
#         -1.4295686 , -1.46254756]])}, {'patient data': ('DA047 Sorted', '12-15', '1'), 'spike label': 2932, 'number of spikes': 124, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[-0.33910486, -0.33910486, -0.33910486, ...,  1.12710847,
#          0.81864862,  0.46790818],
#        [-0.28410651, -0.28410651, -0.28410651, ...,  1.62471811,
#          1.37204551,  1.30398007],
#        [-0.12431732, -0.12431732, -0.12431732, ..., -0.05948036,
#         -0.19093856, -0.28039725],
#        ...,
#        [-0.04183842, -0.04183842, -0.04183842, ..., -0.19865452,
#         -0.47427341, -0.54035424],
#        [ 0.00735016,  0.00735016,  0.00735016, ..., -0.34252383,
#         -0.24258239, -0.12609086],
#        [-1.73807996, -1.73807996, -1.73807996, ...,  0.70086186,
#          0.34282558,  0.14898354]])}, {'patient data': ('DA047 Sorted', '12-15', '1'), 'spike label': 4984, 'number of spikes': 164, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[-0.66935852, -0.66935852, -0.66935852, ..., -0.28938903,
#         -0.38531656, -0.47347729],
#        [-1.03781354, -1.03781354, -1.03781354, ..., -0.62885234,
#         -0.45835444, -0.29583352],
#        [ 0.51146855,  0.51146855,  0.51146855, ..., -0.32078678,
#         -0.44657737, -0.55753509],
#        ...,
#        [-0.08214001, -0.08214001, -0.08214001, ..., -0.02978954,
#         -0.29550184, -0.10895908],
#        [-0.64981935, -0.64981935, -0.64981935, ..., -0.22204938,
#         -0.53137208, -0.52124821],
#        [ 0.65401314,  0.65401314,  0.65401314, ..., -0.72957228,
#         -0.28143476,  0.26613356]])}, {'patient data': ('DA047 Sorted', '12-15', '1'), 'spike label': 5119, 'number of spikes': 186, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[ 0.37118543,  0.41363669,  0.4137601 , ...,  0.54762847,
#          0.54762847,  0.54762847],
#        [ 0.31681273,  0.31681273,  0.31681273, ..., -0.34668966,
#         -0.4188619 , -0.54071622],
#        [ 0.1420793 ,  0.15230807,  0.17027533, ..., -0.02669202,
#         -0.02669202, -0.02669202],
#        ...,
#        [-0.17368052, -0.17368052, -0.17368052, ..., -0.98539093,
#         -1.03328808, -1.02928725],
#        [ 0.30411866,  0.30411866,  0.30411866, ...,  1.4417129 ,
#          1.31195449,  1.17676442],
#        [-1.09633465, -1.09633465, -1.09633465, ..., -1.17208029,
#         -1.45353709, -1.7109484 ]])}, {'patient data': ('DA047 Sorted', '12-15', '1'), 'spike label': 4325, 'number of spikes': 240, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[-0.69263718, -0.69263718, -0.69263718, ...,  1.1243434 ,
#          1.25476576,  1.43086372],
#        [ 0.14310128,  0.14310128,  0.14310128, ..., -0.88471874,
#         -0.81167243, -0.73007718],
#        [ 0.35996508,  0.35996508,  0.35996508, ...,  0.47846601,
#          0.31455945,  0.21350215],
#        ...,
#        [-2.38222115, -2.38222115, -2.38222115, ..., -0.78444376,
#         -0.8709588 , -0.83693477],
#        [ 0.14737953,  0.14737953,  0.14737953, ..., -0.09847472,
#         -0.10539222, -0.05679089],
#        [-0.60168786, -0.60168786, -0.60168786, ...,  1.00237466,
#          1.04578448,  1.01168421]])}, {'patient data': ('DA047 Sorted', '12-15', '1'), 'spike label': 4318, 'number of spikes': 287, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[ 1.67960768e+00,  1.67960768e+00,  1.67960768e+00, ...,
#          4.05384809e-01,  3.38862512e-01,  2.71703799e-01],
#        [ 8.49438015e-01,  8.49438015e-01,  8.49438015e-01, ...,
#          1.16866377e+00,  1.25649019e+00,  1.29377824e+00],
#        [ 6.91573297e-01,  6.91573297e-01,  6.91573297e-01, ...,
#         -2.79513190e-01, -3.16287725e-01, -3.53360959e-01],
#        ...,
#        [ 8.19342936e-01,  8.19342936e-01,  8.19342936e-01, ...,
#         -2.30434505e-02,  4.50117232e-02,  1.43552322e-01],
#        [ 6.70598132e-02,  6.70598132e-02,  6.70598132e-02, ...,
#          8.87091058e-01,  8.44198590e-01,  8.57867819e-01],
#        [ 4.02487549e-01,  4.02487549e-01,  4.02487549e-01, ...,
#          2.06679341e-01,  1.08589080e-01,  1.65521076e-03]])}, {'patient data': ('DA047 Sorted', '12-15', '1'), 'spike label': 4924, 'number of spikes': 474, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[ 0.26638412,  0.26638412,  0.26638412, ...,  0.13111451,
#         -0.26061646, -0.65509509],
#        [-2.78457904, -2.78457904, -2.78457904, ...,  1.38689522,
#          1.60150525,  1.12092293],
#        [ 0.06800706,  0.06800706,  0.06800706, ...,  0.86222956,
#          0.84303104,  0.39691158],
#        ...,
#        [-0.33476184, -0.33476184, -0.33476184, ...,  0.35073703,
#          0.40701724,  0.44257861],
#        [ 0.23752398,  0.23752398,  0.23752398, ..., -0.3372433 ,
#         -0.40367217, -0.43551954],
#        [-0.34420307, -0.34420307, -0.34420307, ...,  0.10062496,
#          0.21604952,  0.19503791]])}, {'patient data': ('DA047 Sorted', '12-15', '1'), 'spike label': 4717, 'number of spikes': 790, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[-1.41505906, -1.41505906, -1.41505906, ...,  0.15372856,
#          0.02380386, -0.10977527],
#        [-0.45257796, -0.45257796, -0.45257796, ...,  0.78354141,
#          0.82272945,  1.07031038],
#        [ 0.40380322,  0.40380322,  0.40380322, ..., -1.34503517,
#         -1.37320153, -1.34012053],
#        ...,
#        [ 0.36290065,  0.36290065,  0.36290065, ...,  0.34621029,
#          0.27875538,  0.09551934],
#        [-0.63819971, -0.63819971, -0.63819971, ...,  0.24386975,
#          0.11997402,  0.01711152],
#        [-0.31502807, -0.31502807, -0.31502807, ...,  0.16709639,
#          0.18819509,  0.2678244 ]])}, {'patient data': ('DA047 Sorted', '12-15', '1'), 'spike label': 5261, 'number of spikes': 1177, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[-0.16012482, -0.16012482, -0.16012482, ..., -2.73659515,
#         -2.79305856, -2.73714244],
#        [-1.16206387, -1.06791569, -0.9354352 , ...,  0.71043069,
#          0.71043069,  0.71043069],
#        [-0.14244171, -0.14244171, -0.14244171, ...,  0.34256782,
#          0.34612939,  0.34542263],
#        ...,
#        [ 0.69356452,  0.69356452,  0.69356452, ..., -0.1425416 ,
#         -0.12095166, -0.02815743],
#        [-0.71593959, -0.71593959, -0.71593959, ..., -0.10523025,
#         -0.10909391, -0.13514251],
#        [-0.02510522, -0.02510522, -0.02510522, ...,  0.15410319,
#          0.19936735,  0.23394218]])}, {'patient data': ('DA047 Sorted', '12-15', '1'), 'spike label': 4775, 'number of spikes': 1880, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[ 0.04744991,  0.04744991,  0.04744991, ...,  0.70833013,
#          0.23949962, -0.48727075],
#        [ 0.75076485,  0.75076485,  0.75076485, ...,  0.24509557,
#          0.22190517,  0.23429393],
#        [ 0.06811236,  0.06811236,  0.06811236, ...,  0.18796853,
#          0.24682419,  0.29937686],
#        ...,
#        [-0.00316964, -0.00316964, -0.00316964, ...,  0.13279608,
#          0.20632343,  0.26454601],
#        [ 0.00883609,  0.00883609,  0.00883609, ...,  1.47639909,
#          1.60426575,  1.53302262],
#        [-0.36706962, -0.36706962, -0.36706962, ..., -0.42160485,
#         -0.47769307, -0.62884348]])}, {'patient data': ('DA047 Sorted', '12-15', '1'), 'spike label': None, 'number of spikes': 0, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([], dtype=float64)}, {'patient data': ('DA047 Sorted', '12-15', '1'), 'spike label': None, 'number of spikes': 0, 'spike_type': 'good_units', 'alignment': 'positive', 'spikes': array([], dtype=float64)}, {'patient data': ('DA047 Sorted', '12-15', '1'), 'spike label': 4717, 'number of spikes': 790, 'spike_type': 'good_units', 'alignment': 'negative', 'spikes': array([[-1.41505906, -1.41505906, -1.41505906, ...,  0.15372856,
#          0.02380386, -0.10977527],
#        [-0.45257796, -0.45257796, -0.45257796, ...,  0.78354141,
#          0.82272945,  1.07031038],
#        [ 0.40380322,  0.40380322,  0.40380322, ..., -1.34503517,
#         -1.37320153, -1.34012053],
#        ...,
#        [ 0.36290065,  0.36290065,  0.36290065, ...,  0.34621029,
#          0.27875538,  0.09551934],
#        [-0.63819971, -0.63819971, -0.63819971, ...,  0.24386975,
#          0.11997402,  0.01711152],
#        [-0.31502807, -0.31502807, -0.31502807, ...,  0.16709639,
#          0.18819509,  0.2678244 ]])}, {'patient data': ('DA047 Sorted', '12-15', '1'), 'spike label': None, 'number of spikes': 0, 'spike_type': 'good_units', 'alignment': 'negative', 'spikes': array([], dtype=float64)}, {'patient data': ('DA047 Sorted', '12-15', '2'), 'spike label': 701, 'number of spikes': 0, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([], shape=(0, 256), dtype=float64)}, {'patient data': ('DA047 Sorted', '12-15', '2'), 'spike label': 4803, 'number of spikes': 0, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([], shape=(0, 256), dtype=float64)}, {'patient data': ('DA047 Sorted', '12-15', '2'), 'spike label': 4963, 'number of spikes': 0, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([], shape=(0, 256), dtype=float64)}, {'patient data': ('DA047 Sorted', '12-15', '2'), 'spike label': 3850, 'number of spikes': 0, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([], shape=(0, 256), dtype=float64)}, {'patient data': ('DA047 Sorted', '12-15', '2'), 'spike label': 2932, 'number of spikes': 0, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([], shape=(0, 256), dtype=float64)}, {'patient data': ('DA047 Sorted', '12-15', '2'), 'spike label': 4984, 'number of spikes': 0, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([], shape=(0, 256), dtype=float64)}, {'patient data': ('DA047 Sorted', '12-15', '2'), 'spike label': None, 'number of spikes': 0, 'spike_type': 'good_units', 'alignment': 'positive', 'spikes': array([], dtype=float64)}, {'patient data': ('DA047 Sorted', '12-15', '2'), 'spike label': 4717, 'number of spikes': 0, 'spike_type': 'good_units', 'alignment': 'negative', 'spikes': array([], shape=(0, 256), dtype=float64)}, {'patient data': ('DA047 Sorted', '12-13', '0'), 'spike label': 701, 'number of spikes': 0, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([], dtype=float64)}, {'patient data': ('DA047 Sorted', '12-13', '0'), 'spike label': 3850, 'number of spikes': 0, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([], dtype=float64)}, {'patient data': ('DA047 Sorted', '12-13', '0'), 'spike label': None, 'number of spikes': 0, 'spike_type': 'good_units', 'alignment': 'positive', 'spikes': array([], dtype=float64)}, {'patient data': ('DA047 Sorted', '12-13', '0'), 'spike label': 4717, 'number of spikes': 0, 'spike_type': 'good_units', 'alignment': 'negative', 'spikes': array([], dtype=float64)}, {'patient data': ('DA047 Sorted', '12-13', '1'), 'spike label': 701, 'number of spikes': 79, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[-0.52701887, -0.52701887, -0.52701887, ..., -0.39468965,
#         -0.58021059, -0.74705469],
#        [ 0.22877798,  0.22877798,  0.22877798, ..., -0.58857936,
#         -0.54955398, -0.55416127],
#        [ 0.57100215,  0.57100215,  0.57100215, ..., -0.00713703,
#          0.19888277,  0.34133471],
#        ...,
#        [-0.6481804 , -0.6481804 , -0.6481804 , ..., -1.36424797,
#         -1.42281428, -1.45733443],
#        [ 0.65367604,  0.65367604,  0.65367604, ..., -0.13056104,
#          0.01292183,  0.12577971],
#        [-0.24687845, -0.24687845, -0.24687845, ..., -1.15873753,
#         -1.22594925, -1.34878511]])}, {'patient data': ('DA047 Sorted', '12-13', '1'), 'spike label': 4803, 'number of spikes': 84, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[-1.79023345, -1.79023345, -1.79023345, ...,  1.15054443,
#          1.20328937,  0.99146787],
#        [ 0.28609088,  0.28609088,  0.28609088, ..., -0.05922048,
#         -0.07564397, -0.0717835 ],
#        [ 1.14897774,  1.14897774,  1.14897774, ...,  0.34387582,
#          0.68148718,  0.99747271],
#        ...,
#        [-1.04365801, -1.04365801, -1.04365801, ...,  0.66511436,
#          0.82711225,  0.97056409],
#        [ 0.20046279,  0.20046279,  0.20046279, ..., -0.12706155,
#         -0.10275103, -0.00437162],
#        [-0.40756574, -0.40756574, -0.40756574, ..., -0.52887413,
#         -0.49660638, -0.41679855]])}, {'patient data': ('DA047 Sorted', '12-13', '1'), 'spike label': 4963, 'number of spikes': 124, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[-0.27057913, -0.27057913, -0.27057913, ...,  0.86395185,
#          0.90125534,  0.86048668],
#        [ 0.51374765,  0.51374765,  0.51374765, ..., -1.04885675,
#         -1.02179134, -0.9718434 ],
#        [-0.50625322, -0.50625322, -0.50625322, ..., -1.02543465,
#         -0.89211196, -0.77763545],
#        ...,
#        [-0.486811  , -0.486811  , -0.486811  , ..., -0.8149116 ,
#         -0.71307022, -0.59044112],
#        [-0.0153786 , -0.0153786 , -0.0153786 , ...,  1.35752312,
#          1.72414962,  1.79066924],
#        [-0.7480665 , -0.7480665 , -0.7480665 , ..., -0.87201777,
#         -0.52830733, -0.18258856]])}, {'patient data': ('DA047 Sorted', '12-13', '1'), 'spike label': 4752, 'number of spikes': 129, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[-1.01059213, -1.01059213, -1.01059213, ..., -0.37879206,
#         -0.42587984, -0.43994185],
#        [ 0.42453209,  0.42453209,  0.42453209, ..., -0.48297434,
#         -0.37454247, -0.24280861],
#        [-0.1507682 , -0.1507682 , -0.1507682 , ..., -0.99137773,
#         -0.88703348, -0.70690804],
#        ...,
#        [ 0.11667829,  0.11667829,  0.11667829, ...,  1.197213  ,
#          1.44156666,  1.65977301],
#        [ 1.30839866,  1.30839866,  1.30839866, ...,  0.90841164,
#          0.79870976,  0.57892243],
#        [ 1.0140663 ,  1.0140663 ,  1.0140663 , ...,  0.29238322,
#          0.56861662,  0.81148683]])}, {'patient data': ('DA047 Sorted', '12-13', '1'), 'spike label': 4701, 'number of spikes': 138, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[-0.54013348, -0.54013348, -0.54013348, ..., -1.03188203,
#         -1.14979515, -1.12145123],
#        [-0.50512488, -0.50512488, -0.50512488, ..., -1.45903963,
#         -1.41227738, -1.35586377],
#        [-0.47547426, -0.47547426, -0.47547426, ..., -0.27363866,
#         -0.15506056,  0.12093351],
#        ...,
#        [ 0.19574029,  0.19574029,  0.19574029, ..., -1.4241772 ,
#         -1.60083837, -1.72998219],
#        [-0.80075579, -0.80075579, -0.80075579, ...,  0.09976946,
#          0.02215386, -0.0616391 ],
#        [ 0.08767616,  0.08767616,  0.08767616, ..., -0.76159073,
#         -0.80186677, -0.83945608]])}, {'patient data': ('DA047 Sorted', '12-13', '1'), 'spike label': 2934, 'number of spikes': 218, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[-1.31874334, -1.31874334, -1.31874334, ...,  2.34395727,
#          2.32699768,  2.72096939],
#        [ 0.78753261,  0.78753261,  0.78753261, ...,  0.02093963,
#          0.05176057,  0.02208206],
#        [-0.45089689, -0.45089689, -0.45089689, ...,  0.08999822,
#         -0.05432042,  0.06340459],
#        ...,
#        [-0.68407099, -0.68407099, -0.68407099, ..., -0.08479122,
#         -0.1510512 , -0.11338694],
#        [ 1.9369842 ,  1.9369842 ,  1.9369842 , ..., -1.33169672,
#         -1.30356435, -1.24723248],
#        [-0.46979218, -0.46979218, -0.46979218, ..., -0.11056359,
#         -0.29550409, -0.46908412]])}, {'patient data': ('DA047 Sorted', '12-13', '1'), 'spike label': 3007, 'number of spikes': 316, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[ 0.05225007,  0.05225007,  0.05225007, ...,  1.96057007,
#          1.7959047 ,  1.56679955],
#        [ 0.16263878,  0.16263878,  0.16263878, ..., -0.80504862,
#         -0.38415578,  0.04389376],
#        [ 0.32460897,  0.32460897,  0.32460897, ...,  0.2113784 ,
#          0.27293996,  0.35070729],
#        ...,
#        [ 1.41382835,  1.41382835,  1.41382835, ...,  0.02601716,
#         -0.03425844, -0.06966663],
#        [-0.04636347, -0.04636347, -0.04636347, ...,  0.43988079,
#          0.46612798,  0.48342214],
#        [ 0.2134538 ,  0.2134538 ,  0.2134538 , ..., -2.21693253,
#         -1.72193294, -1.1746038 ]])}, {'patient data': ('DA047 Sorted', '12-13', '1'), 'spike label': 4651, 'number of spikes': 466, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[-2.6136257 , -2.6136257 , -2.6136257 , ...,  0.9825337 ,
#          1.06606428,  1.05120456],
#        [ 0.26620214,  0.26620214,  0.26620214, ..., -0.84204091,
#         -0.68172896, -0.51600789],
#        [ 0.01604635,  0.01604635,  0.01604635, ...,  0.14596181,
#         -0.15755937, -0.03612232],
#        ...,
#        [ 0.12721072,  0.44059851,  0.66785768, ...,  1.08753277,
#          1.08753277,  1.08753277],
#        [-0.07558714, -0.07558714, -0.07558714, ...,  0.17459092,
#          0.2719415 ,  0.3776348 ],
#        [-0.75241483, -0.75241483, -0.75241483, ...,  0.26650064,
#          0.23839571,  0.26572463]])}, {'patient data': ('DA047 Sorted', '12-13', '1'), 'spike label': 5282, 'number of spikes': 570, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[-0.21299668, -0.21299668, -0.21299668, ...,  0.71974654,
#          0.89918754,  0.99885184],
#        [-0.37814533, -0.37814533, -0.37814533, ...,  0.23386778,
#          0.24975287,  0.2360183 ],
#        [-0.3747489 , -0.3747489 , -0.3747489 , ..., -0.70234714,
#         -0.54892729, -0.42010744],
#        ...,
#        [-0.97866299, -0.97866299, -0.97866299, ..., -1.34717575,
#         -1.34576478, -1.34146563],
#        [-1.04562111, -1.04562111, -1.04562111, ...,  0.13834202,
#          0.12229378,  0.14055224],
#        [ 0.29603209,  0.29603209,  0.29603209, ...,  0.17066741,
#          0.12275709,  0.06386094]])}, {'patient data': ('DA047 Sorted', '12-13', '1'), 'spike label': 5319, 'number of spikes': 671, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[ 0.15132119,  0.15132119,  0.15132119, ...,  1.33568942,
#          1.45183267,  1.57296942],
#        [ 0.4187626 ,  0.39241963,  0.3557863 , ...,  0.84016701,
#          0.84016701,  0.84016701],
#        [-0.45669299, -0.45669299, -0.45669299, ...,  0.15424585,
#          0.47396766,  0.7779399 ],
#        ...,
#        [-1.14452767, -1.14452767, -1.14452767, ..., -0.47157629,
#         -0.638973  , -0.72390708],
#        [ 1.0491679 ,  1.0491679 ,  1.0491679 , ...,  0.30668893,
#          0.34801939,  0.41909122],
#        [-0.75605326, -0.75605326, -0.75605326, ...,  0.65725096,
#          0.71627821,  0.8652912 ]])}, {'patient data': ('DA047 Sorted', '12-13', '1'), 'spike label': 5125, 'number of spikes': 825, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[-0.06581804, -0.06581804, -0.06581804, ...,  0.57784877,
#          0.57308878,  0.52663597],
#        [-0.53579354, -0.53579354, -0.53579354, ..., -0.29643778,
#         -0.39174102, -0.48398135],
#        [-0.19562178, -0.19562178, -0.19562178, ..., -0.50095011,
#         -0.46201907, -0.36833992],
#        ...,
#        [-0.92696632, -0.92696632, -0.92696632, ...,  0.43219971,
#          0.4160524 ,  0.39608096],
#        [ 0.28900757,  0.28900757,  0.28900757, ..., -0.06903951,
#         -0.05934369, -0.03528846],
#        [ 0.03427176,  0.03427176,  0.03427176, ..., -0.23932512,
#         -0.35199625, -0.49126137]])}, {'patient data': ('DA047 Sorted', '12-13', '1'), 'spike label': 4854, 'number of spikes': 856, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[ 2.12347864,  2.12347864,  2.12347864, ..., -2.2457678 ,
#         -2.01117189, -1.86065775],
#        [-0.2980294 , -0.2980294 , -0.2980294 , ..., -0.50777773,
#         -0.47475842, -0.47949465],
#        [ 0.11629926,  0.11629926,  0.11629926, ...,  0.43023675,
#          0.61633531,  0.82718389],
#        ...,
#        [ 0.36888665,  0.36888665,  0.36888665, ..., -0.16754674,
#          0.06285296,  0.29045914],
#        [-1.44109765, -1.44109765, -1.44109765, ..., -0.43801901,
#         -0.52787378, -0.58795533],
#        [-1.40970014, -1.40970014, -1.40970014, ..., -0.07130553,
#          0.07717608,  0.12267639]])}, {'patient data': ('DA047 Sorted', '12-13', '1'), 'spike label': 5128, 'number of spikes': 1591, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[ 2.48813999,  2.48813999,  2.48813999, ..., -1.04228541,
#         -1.57177917, -2.01885354],
#        [ 0.14923497,  0.14923497,  0.14923497, ..., -1.38721215,
#         -1.46606525, -1.32959774],
#        [-0.22777976, -0.22777976, -0.22777976, ..., -1.01845744,
#         -0.78680338, -0.6536088 ],
#        ...,
#        [ 0.37373443,  0.37373443,  0.37373443, ...,  0.02969463,
#          0.02603142,  0.16952536],
#        [-0.06054252, -0.06054252, -0.06054252, ...,  0.73703047,
#          0.72022   ,  0.68492621],
#        [-0.06821664, -0.06821664, -0.06821664, ..., -0.48420315,
#         -0.51311004, -0.51874855]])}, {'patient data': ('DA047 Sorted', '12-13', '1'), 'spike label': None, 'number of spikes': 0, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([], dtype=float64)}, {'patient data': ('DA047 Sorted', '12-13', '1'), 'spike label': 3850, 'number of spikes': 61, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[-0.03415769, -0.03415769, -0.03415769, ...,  1.1071466 ,
#          1.13055098,  1.12063954],
#        [ 0.12779562,  0.12779562,  0.12779562, ...,  2.36771951,
#          2.40197288,  2.22118889],
#        [ 0.87518296,  0.87518296,  0.87518296, ...,  0.82128189,
#          0.69073954,  0.59003041],
#        ...,
#        [ 0.69293414,  0.69293414,  0.69293414, ...,  0.52337957,
#          0.57135711,  0.55564019],
#        [ 0.20410287,  0.20410287,  0.20410287, ...,  0.84395742,
#          0.76494884,  0.67357055],
#        [ 1.06453379,  1.06453379,  1.06453379, ..., -1.43029182,
#         -1.4295686 , -1.46254756]])}, {'patient data': ('DA047 Sorted', '12-13', '1'), 'spike label': 2932, 'number of spikes': 124, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[-0.33910486, -0.33910486, -0.33910486, ...,  1.12710847,
#          0.81864862,  0.46790818],
#        [-0.28410651, -0.28410651, -0.28410651, ...,  1.62471811,
#          1.37204551,  1.30398007],
#        [-0.12431732, -0.12431732, -0.12431732, ..., -0.05948036,
#         -0.19093856, -0.28039725],
#        ...,
#        [-0.04183842, -0.04183842, -0.04183842, ..., -0.19865452,
#         -0.47427341, -0.54035424],
#        [ 0.00735016,  0.00735016,  0.00735016, ..., -0.34252383,
#         -0.24258239, -0.12609086],
#        [-1.73807996, -1.73807996, -1.73807996, ...,  0.70086186,
#          0.34282558,  0.14898354]])}, {'patient data': ('DA047 Sorted', '12-13', '1'), 'spike label': 4984, 'number of spikes': 164, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[-0.66935852, -0.66935852, -0.66935852, ..., -0.28938903,
#         -0.38531656, -0.47347729],
#        [-1.03781354, -1.03781354, -1.03781354, ..., -0.62885234,
#         -0.45835444, -0.29583352],
#        [ 0.51146855,  0.51146855,  0.51146855, ..., -0.32078678,
#         -0.44657737, -0.55753509],
#        ...,
#        [-0.08214001, -0.08214001, -0.08214001, ..., -0.02978954,
#         -0.29550184, -0.10895908],
#        [-0.64981935, -0.64981935, -0.64981935, ..., -0.22204938,
#         -0.53137208, -0.52124821],
#        [ 0.65401314,  0.65401314,  0.65401314, ..., -0.72957228,
#         -0.28143476,  0.26613356]])}, {'patient data': ('DA047 Sorted', '12-13', '1'), 'spike label': 5119, 'number of spikes': 186, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[ 0.37118543,  0.41363669,  0.4137601 , ...,  0.54762847,
#          0.54762847,  0.54762847],
#        [ 0.31681273,  0.31681273,  0.31681273, ..., -0.34668966,
#         -0.4188619 , -0.54071622],
#        [ 0.1420793 ,  0.15230807,  0.17027533, ..., -0.02669202,
#         -0.02669202, -0.02669202],
#        ...,
#        [-0.17368052, -0.17368052, -0.17368052, ..., -0.98539093,
#         -1.03328808, -1.02928725],
#        [ 0.30411866,  0.30411866,  0.30411866, ...,  1.4417129 ,
#          1.31195449,  1.17676442],
#        [-1.09633465, -1.09633465, -1.09633465, ..., -1.17208029,
#         -1.45353709, -1.7109484 ]])}, {'patient data': ('DA047 Sorted', '12-13', '1'), 'spike label': 4325, 'number of spikes': 240, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[-0.69263718, -0.69263718, -0.69263718, ...,  1.1243434 ,
#          1.25476576,  1.43086372],
#        [ 0.14310128,  0.14310128,  0.14310128, ..., -0.88471874,
#         -0.81167243, -0.73007718],
#        [ 0.35996508,  0.35996508,  0.35996508, ...,  0.47846601,
#          0.31455945,  0.21350215],
#        ...,
#        [-2.38222115, -2.38222115, -2.38222115, ..., -0.78444376,
#         -0.8709588 , -0.83693477],
#        [ 0.14737953,  0.14737953,  0.14737953, ..., -0.09847472,
#         -0.10539222, -0.05679089],
#        [-0.60168786, -0.60168786, -0.60168786, ...,  1.00237466,
#          1.04578448,  1.01168421]])}, {'patient data': ('DA047 Sorted', '12-13', '1'), 'spike label': 4318, 'number of spikes': 287, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[ 1.67960768e+00,  1.67960768e+00,  1.67960768e+00, ...,
#          4.05384809e-01,  3.38862512e-01,  2.71703799e-01],
#        [ 8.49438015e-01,  8.49438015e-01,  8.49438015e-01, ...,
#          1.16866377e+00,  1.25649019e+00,  1.29377824e+00],
#        [ 6.91573297e-01,  6.91573297e-01,  6.91573297e-01, ...,
#         -2.79513190e-01, -3.16287725e-01, -3.53360959e-01],
#        ...,
#        [ 8.19342936e-01,  8.19342936e-01,  8.19342936e-01, ...,
#         -2.30434505e-02,  4.50117232e-02,  1.43552322e-01],
#        [ 6.70598132e-02,  6.70598132e-02,  6.70598132e-02, ...,
#          8.87091058e-01,  8.44198590e-01,  8.57867819e-01],
#        [ 4.02487549e-01,  4.02487549e-01,  4.02487549e-01, ...,
#          2.06679341e-01,  1.08589080e-01,  1.65521076e-03]])}, {'patient data': ('DA047 Sorted', '12-13', '1'), 'spike label': 4924, 'number of spikes': 474, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[ 0.26638412,  0.26638412,  0.26638412, ...,  0.13111451,
#         -0.26061646, -0.65509509],
#        [-2.78457904, -2.78457904, -2.78457904, ...,  1.38689522,
#          1.60150525,  1.12092293],
#        [ 0.06800706,  0.06800706,  0.06800706, ...,  0.86222956,
#          0.84303104,  0.39691158],
#        ...,
#        [-0.33476184, -0.33476184, -0.33476184, ...,  0.35073703,
#          0.40701724,  0.44257861],
#        [ 0.23752398,  0.23752398,  0.23752398, ..., -0.3372433 ,
#         -0.40367217, -0.43551954],
#        [-0.34420307, -0.34420307, -0.34420307, ...,  0.10062496,
#          0.21604952,  0.19503791]])}, {'patient data': ('DA047 Sorted', '12-13', '1'), 'spike label': 4717, 'number of spikes': 790, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[-1.41505906, -1.41505906, -1.41505906, ...,  0.15372856,
#          0.02380386, -0.10977527],
#        [-0.45257796, -0.45257796, -0.45257796, ...,  0.78354141,
#          0.82272945,  1.07031038],
#        [ 0.40380322,  0.40380322,  0.40380322, ..., -1.34503517,
#         -1.37320153, -1.34012053],
#        ...,
#        [ 0.36290065,  0.36290065,  0.36290065, ...,  0.34621029,
#          0.27875538,  0.09551934],
#        [-0.63819971, -0.63819971, -0.63819971, ...,  0.24386975,
#          0.11997402,  0.01711152],
#        [-0.31502807, -0.31502807, -0.31502807, ...,  0.16709639,
#          0.18819509,  0.2678244 ]])}, {'patient data': ('DA047 Sorted', '12-13', '1'), 'spike label': 5261, 'number of spikes': 1177, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[-0.16012482, -0.16012482, -0.16012482, ..., -2.73659515,
#         -2.79305856, -2.73714244],
#        [-1.16206387, -1.06791569, -0.9354352 , ...,  0.71043069,
#          0.71043069,  0.71043069],
#        [-0.14244171, -0.14244171, -0.14244171, ...,  0.34256782,
#          0.34612939,  0.34542263],
#        ...,
#        [ 0.69356452,  0.69356452,  0.69356452, ..., -0.1425416 ,
#         -0.12095166, -0.02815743],
#        [-0.71593959, -0.71593959, -0.71593959, ..., -0.10523025,
#         -0.10909391, -0.13514251],
#        [-0.02510522, -0.02510522, -0.02510522, ...,  0.15410319,
#          0.19936735,  0.23394218]])}, {'patient data': ('DA047 Sorted', '12-13', '1'), 'spike label': 4775, 'number of spikes': 1880, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[ 0.04744991,  0.04744991,  0.04744991, ...,  0.70833013,
#          0.23949962, -0.48727075],
#        [ 0.75076485,  0.75076485,  0.75076485, ...,  0.24509557,
#          0.22190517,  0.23429393],
#        [ 0.06811236,  0.06811236,  0.06811236, ...,  0.18796853,
#          0.24682419,  0.29937686],
#        ...,
#        [-0.00316964, -0.00316964, -0.00316964, ...,  0.13279608,
#          0.20632343,  0.26454601],
#        [ 0.00883609,  0.00883609,  0.00883609, ...,  1.47639909,
#          1.60426575,  1.53302262],
#        [-0.36706962, -0.36706962, -0.36706962, ..., -0.42160485,
# ...
#        [ 0.16263878,  0.16263878,  0.16263878, ..., -0.80504862,
#         -0.38415578,  0.04389376],
#        [ 0.32460897,  0.32460897,  0.32460897, ...,  0.2113784 ,
#          0.27293996,  0.35070729],
#        ...,
#        [ 1.41382835,  1.41382835,  1.41382835, ...,  0.02601716,
#         -0.03425844, -0.06966663],
#        [-0.04636347, -0.04636347, -0.04636347, ...,  0.43988079,
#          0.46612798,  0.48342214],
#        [ 0.2134538 ,  0.2134538 ,  0.2134538 , ..., -2.21693253,
#         -1.72193294, -1.1746038 ]])}, {'patient data': ('DA047 Sorted', '12-16', '1'), 'spike label': 4651, 'number of spikes': 466, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[-2.6136257 , -2.6136257 , -2.6136257 , ...,  0.9825337 ,
#          1.06606428,  1.05120456],
#        [ 0.26620214,  0.26620214,  0.26620214, ..., -0.84204091,
#         -0.68172896, -0.51600789],
#        [ 0.01604635,  0.01604635,  0.01604635, ...,  0.14596181,
#         -0.15755937, -0.03612232],
#        ...,
#        [ 0.12721072,  0.44059851,  0.66785768, ...,  1.08753277,
#          1.08753277,  1.08753277],
#        [-0.07558714, -0.07558714, -0.07558714, ...,  0.17459092,
#          0.2719415 ,  0.3776348 ],
#        [-0.75241483, -0.75241483, -0.75241483, ...,  0.26650064,
#          0.23839571,  0.26572463]])}, {'patient data': ('DA047 Sorted', '12-16', '1'), 'spike label': 5282, 'number of spikes': 570, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[-0.21299668, -0.21299668, -0.21299668, ...,  0.71974654,
#          0.89918754,  0.99885184],
#        [-0.37814533, -0.37814533, -0.37814533, ...,  0.23386778,
#          0.24975287,  0.2360183 ],
#        [-0.3747489 , -0.3747489 , -0.3747489 , ..., -0.70234714,
#         -0.54892729, -0.42010744],
#        ...,
#        [-0.97866299, -0.97866299, -0.97866299, ..., -1.34717575,
#         -1.34576478, -1.34146563],
#        [-1.04562111, -1.04562111, -1.04562111, ...,  0.13834202,
#          0.12229378,  0.14055224],
#        [ 0.29603209,  0.29603209,  0.29603209, ...,  0.17066741,
#          0.12275709,  0.06386094]])}, {'patient data': ('DA047 Sorted', '12-16', '1'), 'spike label': 5319, 'number of spikes': 671, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[ 0.15132119,  0.15132119,  0.15132119, ...,  1.33568942,
#          1.45183267,  1.57296942],
#        [ 0.4187626 ,  0.39241963,  0.3557863 , ...,  0.84016701,
#          0.84016701,  0.84016701],
#        [-0.45669299, -0.45669299, -0.45669299, ...,  0.15424585,
#          0.47396766,  0.7779399 ],
#        ...,
#        [-1.14452767, -1.14452767, -1.14452767, ..., -0.47157629,
#         -0.638973  , -0.72390708],
#        [ 1.0491679 ,  1.0491679 ,  1.0491679 , ...,  0.30668893,
#          0.34801939,  0.41909122],
#        [-0.75605326, -0.75605326, -0.75605326, ...,  0.65725096,
#          0.71627821,  0.8652912 ]])}, {'patient data': ('DA047 Sorted', '12-16', '1'), 'spike label': 5125, 'number of spikes': 825, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[-0.06581804, -0.06581804, -0.06581804, ...,  0.57784877,
#          0.57308878,  0.52663597],
#        [-0.53579354, -0.53579354, -0.53579354, ..., -0.29643778,
#         -0.39174102, -0.48398135],
#        [-0.19562178, -0.19562178, -0.19562178, ..., -0.50095011,
#         -0.46201907, -0.36833992],
#        ...,
#        [-0.92696632, -0.92696632, -0.92696632, ...,  0.43219971,
#          0.4160524 ,  0.39608096],
#        [ 0.28900757,  0.28900757,  0.28900757, ..., -0.06903951,
#         -0.05934369, -0.03528846],
#        [ 0.03427176,  0.03427176,  0.03427176, ..., -0.23932512,
#         -0.35199625, -0.49126137]])}, {'patient data': ('DA047 Sorted', '12-16', '1'), 'spike label': 4854, 'number of spikes': 856, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[ 2.12347864,  2.12347864,  2.12347864, ..., -2.2457678 ,
#         -2.01117189, -1.86065775],
#        [-0.2980294 , -0.2980294 , -0.2980294 , ..., -0.50777773,
#         -0.47475842, -0.47949465],
#        [ 0.11629926,  0.11629926,  0.11629926, ...,  0.43023675,
#          0.61633531,  0.82718389],
#        ...,
#        [ 0.36888665,  0.36888665,  0.36888665, ..., -0.16754674,
#          0.06285296,  0.29045914],
#        [-1.44109765, -1.44109765, -1.44109765, ..., -0.43801901,
#         -0.52787378, -0.58795533],
#        [-1.40970014, -1.40970014, -1.40970014, ..., -0.07130553,
#          0.07717608,  0.12267639]])}, {'patient data': ('DA047 Sorted', '12-16', '1'), 'spike label': 5128, 'number of spikes': 1591, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([[ 2.48813999,  2.48813999,  2.48813999, ..., -1.04228541,
#         -1.57177917, -2.01885354],
#        [ 0.14923497,  0.14923497,  0.14923497, ..., -1.38721215,
#         -1.46606525, -1.32959774],
#        [-0.22777976, -0.22777976, -0.22777976, ..., -1.01845744,
#         -0.78680338, -0.6536088 ],
#        ...,
#        [ 0.37373443,  0.37373443,  0.37373443, ...,  0.02969463,
#          0.02603142,  0.16952536],
#        [-0.06054252, -0.06054252, -0.06054252, ...,  0.73703047,
#          0.72022   ,  0.68492621],
#        [-0.06821664, -0.06821664, -0.06821664, ..., -0.48420315,
#         -0.51311004, -0.51874855]])}, {'patient data': ('DA047 Sorted', '12-16', '1'), 'spike label': None, 'number of spikes': 0, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([], dtype=float64)}, {'patient data': ('DA047 Sorted', '12-16', '1'), 'spike label': 3850, 'number of spikes': 61, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[-0.03415769, -0.03415769, -0.03415769, ...,  1.1071466 ,
#          1.13055098,  1.12063954],
#        [ 0.12779562,  0.12779562,  0.12779562, ...,  2.36771951,
#          2.40197288,  2.22118889],
#        [ 0.87518296,  0.87518296,  0.87518296, ...,  0.82128189,
#          0.69073954,  0.59003041],
#        ...,
#        [ 0.69293414,  0.69293414,  0.69293414, ...,  0.52337957,
#          0.57135711,  0.55564019],
#        [ 0.20410287,  0.20410287,  0.20410287, ...,  0.84395742,
#          0.76494884,  0.67357055],
#        [ 1.06453379,  1.06453379,  1.06453379, ..., -1.43029182,
#         -1.4295686 , -1.46254756]])}, {'patient data': ('DA047 Sorted', '12-16', '1'), 'spike label': 2932, 'number of spikes': 124, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[-0.33910486, -0.33910486, -0.33910486, ...,  1.12710847,
#          0.81864862,  0.46790818],
#        [-0.28410651, -0.28410651, -0.28410651, ...,  1.62471811,
#          1.37204551,  1.30398007],
#        [-0.12431732, -0.12431732, -0.12431732, ..., -0.05948036,
#         -0.19093856, -0.28039725],
#        ...,
#        [-0.04183842, -0.04183842, -0.04183842, ..., -0.19865452,
#         -0.47427341, -0.54035424],
#        [ 0.00735016,  0.00735016,  0.00735016, ..., -0.34252383,
#         -0.24258239, -0.12609086],
#        [-1.73807996, -1.73807996, -1.73807996, ...,  0.70086186,
#          0.34282558,  0.14898354]])}, {'patient data': ('DA047 Sorted', '12-16', '1'), 'spike label': 4984, 'number of spikes': 164, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[-0.66935852, -0.66935852, -0.66935852, ..., -0.28938903,
#         -0.38531656, -0.47347729],
#        [-1.03781354, -1.03781354, -1.03781354, ..., -0.62885234,
#         -0.45835444, -0.29583352],
#        [ 0.51146855,  0.51146855,  0.51146855, ..., -0.32078678,
#         -0.44657737, -0.55753509],
#        ...,
#        [-0.08214001, -0.08214001, -0.08214001, ..., -0.02978954,
#         -0.29550184, -0.10895908],
#        [-0.64981935, -0.64981935, -0.64981935, ..., -0.22204938,
#         -0.53137208, -0.52124821],
#        [ 0.65401314,  0.65401314,  0.65401314, ..., -0.72957228,
#         -0.28143476,  0.26613356]])}, {'patient data': ('DA047 Sorted', '12-16', '1'), 'spike label': 5119, 'number of spikes': 186, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[ 0.37118543,  0.41363669,  0.4137601 , ...,  0.54762847,
#          0.54762847,  0.54762847],
#        [ 0.31681273,  0.31681273,  0.31681273, ..., -0.34668966,
#         -0.4188619 , -0.54071622],
#        [ 0.1420793 ,  0.15230807,  0.17027533, ..., -0.02669202,
#         -0.02669202, -0.02669202],
#        ...,
#        [-0.17368052, -0.17368052, -0.17368052, ..., -0.98539093,
#         -1.03328808, -1.02928725],
#        [ 0.30411866,  0.30411866,  0.30411866, ...,  1.4417129 ,
#          1.31195449,  1.17676442],
#        [-1.09633465, -1.09633465, -1.09633465, ..., -1.17208029,
#         -1.45353709, -1.7109484 ]])}, {'patient data': ('DA047 Sorted', '12-16', '1'), 'spike label': 4325, 'number of spikes': 240, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[-0.69263718, -0.69263718, -0.69263718, ...,  1.1243434 ,
#          1.25476576,  1.43086372],
#        [ 0.14310128,  0.14310128,  0.14310128, ..., -0.88471874,
#         -0.81167243, -0.73007718],
#        [ 0.35996508,  0.35996508,  0.35996508, ...,  0.47846601,
#          0.31455945,  0.21350215],
#        ...,
#        [-2.38222115, -2.38222115, -2.38222115, ..., -0.78444376,
#         -0.8709588 , -0.83693477],
#        [ 0.14737953,  0.14737953,  0.14737953, ..., -0.09847472,
#         -0.10539222, -0.05679089],
#        [-0.60168786, -0.60168786, -0.60168786, ...,  1.00237466,
#          1.04578448,  1.01168421]])}, {'patient data': ('DA047 Sorted', '12-16', '1'), 'spike label': 4318, 'number of spikes': 287, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[ 1.67960768e+00,  1.67960768e+00,  1.67960768e+00, ...,
#          4.05384809e-01,  3.38862512e-01,  2.71703799e-01],
#        [ 8.49438015e-01,  8.49438015e-01,  8.49438015e-01, ...,
#          1.16866377e+00,  1.25649019e+00,  1.29377824e+00],
#        [ 6.91573297e-01,  6.91573297e-01,  6.91573297e-01, ...,
#         -2.79513190e-01, -3.16287725e-01, -3.53360959e-01],
#        ...,
#        [ 8.19342936e-01,  8.19342936e-01,  8.19342936e-01, ...,
#         -2.30434505e-02,  4.50117232e-02,  1.43552322e-01],
#        [ 6.70598132e-02,  6.70598132e-02,  6.70598132e-02, ...,
#          8.87091058e-01,  8.44198590e-01,  8.57867819e-01],
#        [ 4.02487549e-01,  4.02487549e-01,  4.02487549e-01, ...,
#          2.06679341e-01,  1.08589080e-01,  1.65521076e-03]])}, {'patient data': ('DA047 Sorted', '12-16', '1'), 'spike label': 4924, 'number of spikes': 474, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[ 0.26638412,  0.26638412,  0.26638412, ...,  0.13111451,
#         -0.26061646, -0.65509509],
#        [-2.78457904, -2.78457904, -2.78457904, ...,  1.38689522,
#          1.60150525,  1.12092293],
#        [ 0.06800706,  0.06800706,  0.06800706, ...,  0.86222956,
#          0.84303104,  0.39691158],
#        ...,
#        [-0.33476184, -0.33476184, -0.33476184, ...,  0.35073703,
#          0.40701724,  0.44257861],
#        [ 0.23752398,  0.23752398,  0.23752398, ..., -0.3372433 ,
#         -0.40367217, -0.43551954],
#        [-0.34420307, -0.34420307, -0.34420307, ...,  0.10062496,
#          0.21604952,  0.19503791]])}, {'patient data': ('DA047 Sorted', '12-16', '1'), 'spike label': 4717, 'number of spikes': 790, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[-1.41505906, -1.41505906, -1.41505906, ...,  0.15372856,
#          0.02380386, -0.10977527],
#        [-0.45257796, -0.45257796, -0.45257796, ...,  0.78354141,
#          0.82272945,  1.07031038],
#        [ 0.40380322,  0.40380322,  0.40380322, ..., -1.34503517,
#         -1.37320153, -1.34012053],
#        ...,
#        [ 0.36290065,  0.36290065,  0.36290065, ...,  0.34621029,
#          0.27875538,  0.09551934],
#        [-0.63819971, -0.63819971, -0.63819971, ...,  0.24386975,
#          0.11997402,  0.01711152],
#        [-0.31502807, -0.31502807, -0.31502807, ...,  0.16709639,
#          0.18819509,  0.2678244 ]])}, {'patient data': ('DA047 Sorted', '12-16', '1'), 'spike label': 5261, 'number of spikes': 1177, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[-0.16012482, -0.16012482, -0.16012482, ..., -2.73659515,
#         -2.79305856, -2.73714244],
#        [-1.16206387, -1.06791569, -0.9354352 , ...,  0.71043069,
#          0.71043069,  0.71043069],
#        [-0.14244171, -0.14244171, -0.14244171, ...,  0.34256782,
#          0.34612939,  0.34542263],
#        ...,
#        [ 0.69356452,  0.69356452,  0.69356452, ..., -0.1425416 ,
#         -0.12095166, -0.02815743],
#        [-0.71593959, -0.71593959, -0.71593959, ..., -0.10523025,
#         -0.10909391, -0.13514251],
#        [-0.02510522, -0.02510522, -0.02510522, ...,  0.15410319,
#          0.19936735,  0.23394218]])}, {'patient data': ('DA047 Sorted', '12-16', '1'), 'spike label': 4775, 'number of spikes': 1880, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([[ 0.04744991,  0.04744991,  0.04744991, ...,  0.70833013,
#          0.23949962, -0.48727075],
#        [ 0.75076485,  0.75076485,  0.75076485, ...,  0.24509557,
#          0.22190517,  0.23429393],
#        [ 0.06811236,  0.06811236,  0.06811236, ...,  0.18796853,
#          0.24682419,  0.29937686],
#        ...,
#        [-0.00316964, -0.00316964, -0.00316964, ...,  0.13279608,
#          0.20632343,  0.26454601],
#        [ 0.00883609,  0.00883609,  0.00883609, ...,  1.47639909,
#          1.60426575,  1.53302262],
#        [-0.36706962, -0.36706962, -0.36706962, ..., -0.42160485,
#         -0.47769307, -0.62884348]])}, {'patient data': ('DA047 Sorted', '12-16', '1'), 'spike label': None, 'number of spikes': 0, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([], dtype=float64)}, {'patient data': ('DA047 Sorted', '12-16', '1'), 'spike label': None, 'number of spikes': 0, 'spike_type': 'good_units', 'alignment': 'positive', 'spikes': array([], dtype=float64)}, {'patient data': ('DA047 Sorted', '12-16', '1'), 'spike label': 4717, 'number of spikes': 790, 'spike_type': 'good_units', 'alignment': 'negative', 'spikes': array([[-1.41505906, -1.41505906, -1.41505906, ...,  0.15372856,
#          0.02380386, -0.10977527],
#        [-0.45257796, -0.45257796, -0.45257796, ...,  0.78354141,
#          0.82272945,  1.07031038],
#        [ 0.40380322,  0.40380322,  0.40380322, ..., -1.34503517,
#         -1.37320153, -1.34012053],
#        ...,
#        [ 0.36290065,  0.36290065,  0.36290065, ...,  0.34621029,
#          0.27875538,  0.09551934],
#        [-0.63819971, -0.63819971, -0.63819971, ...,  0.24386975,
#          0.11997402,  0.01711152],
#        [-0.31502807, -0.31502807, -0.31502807, ...,  0.16709639,
#          0.18819509,  0.2678244 ]])}, {'patient data': ('DA047 Sorted', '12-16', '1'), 'spike label': None, 'number of spikes': 0, 'spike_type': 'good_units', 'alignment': 'negative', 'spikes': array([], dtype=float64)}, {'patient data': ('DA047 Sorted', '12-16', '2'), 'spike label': 701, 'number of spikes': 0, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([], shape=(0, 256), dtype=float64)}, {'patient data': ('DA047 Sorted', '12-16', '2'), 'spike label': 4803, 'number of spikes': 0, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([], shape=(0, 256), dtype=float64)}, {'patient data': ('DA047 Sorted', '12-16', '2'), 'spike label': 4963, 'number of spikes': 0, 'spike_type': 'noise', 'alignment': 'positive', 'spikes': array([], shape=(0, 256), dtype=float64)}, {'patient data': ('DA047 Sorted', '12-16', '2'), 'spike label': 3850, 'number of spikes': 0, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([], shape=(0, 256), dtype=float64)}, {'patient data': ('DA047 Sorted', '12-16', '2'), 'spike label': 2932, 'number of spikes': 0, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([], shape=(0, 256), dtype=float64)}, {'patient data': ('DA047 Sorted', '12-16', '2'), 'spike label': 4984, 'number of spikes': 0, 'spike_type': 'noise', 'alignment': 'negative', 'spikes': array([], shape=(0, 256), dtype=float64)}, {'patient data': ('DA047 Sorted', '12-16', '2'), 'spike label': None, 'number of spikes': 0, 'spike_type': 'good_units', 'alignment': 'positive', 'spikes': array([], dtype=float64)}, {'patient data': ('DA047 Sorted', '12-16', '2'), 'spike label': 4717, 'number of spikes': 0, 'spike_type': 'good_units', 'alignment': 'negative', 'spikes': array([], shape=(0, 256), dtype=float64)}]

# %%
print(DA047_Bag)
# Out:
# 0

# %%
patient = "DA047 Sorted"
session = "12-13"

base_path = Path("/Users/marco/Local_Sorting")
patient_path = base_path / patient
session_path = patient_path / session
sort_path = session_path / "sort"
raw_path = session_path / "raw/micros"

positive_dir = sort_path / "5.1"
negative_dir = sort_path / "5.2"
final_dir = sort_path / "final"



raw_file = si.read_neuralynx(raw_path)
num_channels = len(raw_file.channel_ids)
print(num_channels)
# Out:
# 16

# %%
import os

def list_subdirectories(dir_path):
    file_list = [name for name in os.listdir(dir_path) if os.path.isdir(os.path.join(dir_path, name))]
    print(dir_path, "contains", file_list)
    return file_list

# Example usage:
subdirs = list_subdirectories(patient_path)
# Out:
# /Users/marco/Local_Sorting/DA047 Sorted contains ['12-15', '12-13', '12-16']
